# %%
import numpy as np
import  pandas as pd
import  matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
advertising=pd.read_csv('Advertising.csv')
advertising.drop('Unnamed: 0',axis=1,inplace=True)

# %%
advertising
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
advertising.shape
# Out:
# (200, 4)

# %%
advertising.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
advertising.describe().T
# Out:
#            count      mean        std  min     25%     50%      75%    max
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# Radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# Newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# Sales      200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %%
plt.figure(figsize=(10,6))
sns.pairplot(advertising,x_vars=advertising.columns,y_vars='Sales',kind='reg')

# %%
sns.heatmap(advertising.corr(),annot=True,cmap='gray')
# Out:
# <Axes: >

# %%
x=np.reshape(advertising['TV'].values,(-1,1))
y=np.reshape(advertising['Sales'].values,(-1,1))

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7)

# %%
lin=LinearRegression()

# %%
lin.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lin.predict(x_test)

# %%
print(metrics.r2_score(y_test,y_pred))
# Out:
# 0.678639327379511

# %%
res=(y_test-y_pred)

# %%
res
# Out:
# array([[-1.44780906],
#        [-1.11835747],
#        [-1.35017974],
#        [-3.86057589],
#        [ 1.01003465],
#        [ 2.14978919],
#        [-1.15014868],
#        [ 1.33260416],
#        [ 1.94414369],
#        [ 0.48479309],
#        [ 0.53028633],
#        [ 2.92831022],
#        [-6.08872877],
#        [ 5.98521873],
#        [ 2.01439072],
#        [-3.29398897],
#        [-2.51228633],
#        [ 0.33344616],
#        [-2.34954592],
#        [ 3.83611822],
#        [ 1.72046187],
#        [ 0.24525601],
#        [ 3.2607881 ],
#        [-0.21370002],
#        [-0.30087106],
#        [-0.83029158],
#        [ 0.21911031],
#        [-1.9940511 ],
#        [ 1.96000823],
#        [ 0.32986996],
#        [-0.52830619],
#        [ 1.02451656],
#        [-3.26415209],
#        [-4.97259392],
#        [ 4.68933555],
#        [ 2.0549562 ],
#        [ 2.06315878],
#        [-0.92902393],
#        [ 1.24068248],
#        [ 3.31806012],
#        [ 5.45426953],
# ...

# %%
sns.displot(res,bins=20)

# %%
print(metrics.mean_squared_error(y_test,y_pred))
# Out:
# 7.5708789554798575

# %%
r2=metrics.r2_score(y_test,y_pred)
r2
# Out:
# 0.678639327379511

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test, lin.intercept_ + lin.coef_*x_test, 'r')

# %%
scaler=StandardScaler()

# %%
x_scaled=scaler.fit_transform(x)
y_scaled=scaler.fit_transform(y)

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y_scaled,train_size=0.7)
x_train
# Out:
# array([[-0.3986778 ],
#        [-0.09157591],
#        [-0.30409509],
#        [ 0.94883389],
#        [-0.14879261],
#        [-0.82605152],
#        [-1.15300409],
#        [-1.06075676],
#        [-1.70882347],
#        [-0.07873135],
#        [ 1.07727954],
#        [-0.1791525 ],
#        [ 0.21669366],
#        [ 0.29726411],
#        [ 0.54481392],
#        [ 0.87994031],
#        [ 1.59456522],
#        [-0.43487612],
#        [ 1.05509347],
#        [ 1.38438142],
#        [-0.10675585],
#        [-0.13828342],
#        [ 0.99320602],
#        [-0.66958136],
#        [-0.71628887],
#        [-1.61891151],
#        [-0.69877355],
#        [ 0.27040729],
#        [-1.09228433],
#        [-0.04837147],
#        [ 0.83440049],
#        [-0.34846722],
#        [-0.94515567],
#        [-0.8377284 ],
#        [-0.80386545],
#        [ 0.73047627],
#        [ 1.35285385],
#        [ 1.02123053],
#        [-1.49863967],
#        [ 0.34981006],
#        [-1.5628625 ],
# ...

# %%
lin.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lin.predict(x_test)

# %%
print(metrics.r2_score(y_test,y_pred))
# Out:
# 0.532045319811068
