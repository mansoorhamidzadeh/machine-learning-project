# %%
from sqlalchemy import create_engine
import psycopg2
import pandas as pd

# %%
DATABASES={
    'knn':{
        'NAME': 'knn_db',
        'USER': 'we',
        'PASSWORD': 'qwa1',
        'HOST': 'localhost',
        'PORT': 5432,
    }
}
db=DATABASES['knn']

# %%
engine_string = "postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}".format(
    user = db['USER'],
    password = db['PASSWORD'],
    host = db['HOST'],
    port = db['PORT'],
    database = db['NAME'],
)

# %%
engine = create_engine(engine_string)
df=pd.read_sql_table('social_network',engine)
df
# Out:
#      age  estimatedsalary  purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]
