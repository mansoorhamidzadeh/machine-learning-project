# %%
import pandas as pd
import nltk

# %%
data=pd.read_csv('per.csv')

# %%
data
# Out:
#        NewsID                                              Title  \
# 0      843656  \nوزير علوم درجمع استادان نمونه: سن بازنشستگي ...
# 1      837144  \nگردهمايي دانش‌آموختگان موسسه آموزش عالي سوره...
# 2      436862  \nنتايج آزمون دوره‌هاي فراگير دانشگاه پيام‌نور...
# 3      227781  \nهمايش يكروزه آسيب شناسي مفهوم روابط عمومي در...
# 4      174187  \nوضعيت اقتصادي و ميزان تحصيلات والدين از مهمت...
# ...       ...                                                ...
# 10994  252520              \n/گزارش/ «حقي» حق خود را با طلا گرفت
# 10995  899807  \nمدير تيم‌هاي ملي كشتي فرنگي: نفرات اول تا سو...
# 10996  432925  \nتساوي چلسي و ادامه صدرنشيني آرسنال تساوي اشت...
# 10997  736914  \nشكست ايران از پرتغال در آيينه‌ي خبرگزاري‌ها:...
# 10998  681439  \nهادي شكوري: صدر جدول را تصاحب كنيم ديگر آن ر...
#
#                                                     Body         Date  \
# 0      \nوزير علوم در جمع استادان نمونه كشور گفت: از ...  \n138/5//09
# ...

# %%
with open('stopwords.txt', encoding="utf8") as f:
    stop=f.readlines()
stop=[line.replace('\n','') for line in stop]
stop
# Out:
# ['!',
#  '"',
#  '#',
#  '(',
#  ')',
#  '*',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  '[',
#  ']',
#  '«',
#  '»',
#  '،',
#  '؛',
#  '؟',
#  'آباد',
#  'آخ',
#  'آخر',
#  'آخرها',
#  'آخه',
#  'آدمهاست',
#  'آرام',
#  'آرام آرام',
#  'آره',
#  'آری',
#  'آزادانه',
#  'آسان',
#  'آسیب پذیرند',
#  'آشنایند',
#  'آشکارا',
#  'آقا',
#  'آقای',
#  'آقایان',
#  'آمد',
#  'آمدن',
#  'آمده',
#  'آمرانه',
#  'آن',
#  'آن گاه',
#  'آنان',
#  'آنانی',
#  'آنجا',
#  'آنرا',
#  'آنطور',
#  'آنقدر',
#  'آنها',
#  'آنهاست',
#  'آنچنان',
#  'آنچنان که',
#  'آنچه',
#  'آنکه',
#  'آنگاه',
#  'آن\u200cها',
#  'آهان',
#  'آهای',
#  'آور',
#  'آورد',
#  'آوردن',
#  'آورده',
#  'آوه',
#  'آی',
#  'آیا',
#  'آید',
#  'آیند',
#  'ا',
#  'اتفاقا',
#  'اثرِ',
#  'اجراست',
#  'احتراما',
#  'احتمالا',
#  'احیاناً',
#  'اخیر',
#  'اخیراً',
#  'اری',
#  'از',
#  'از آن پس',
#  'از جمله',
#  'ازاین رو',
#  'ازجمله',
#  'ازش',
#  'اساسا',
#  'اساساً',
#  'است',
#  'استفاد',
#  'استفاده',
#  'اسلامی اند',
# ...

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\we\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\we\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
nltk_sto=nltk.corpus.stopwords.words('english')
stop.extend(nltk_sto)

# %%
len(stop)
# Out:
# 1495

# %%
import hazm
stemmer=hazm.Stemmer()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 import hazm
#       2 stemmer=hazm.Stemmer()
#
# ModuleNotFoundError: No module named 'hazm'
