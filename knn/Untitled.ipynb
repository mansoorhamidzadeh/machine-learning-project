# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# %matplotlib inline

# %%
iris=load_iris()

# %%
iris.keys()
iris.target
np.unique(iris.target,return_counts=True)
x=iris.data[:,[2,3]]

y=iris.target
iris.feature_names
plt.scatter(x[:,0],x[:,1],c=y)

# %%
df=pd.DataFrame(iris.data,columns=iris.feature_names)
df['target']=iris.target

# %%
df.plot(kind='box',sharex=False,sharey=False)
plt.figure(figsize=(8, 6), dpi=80)
plt.show()

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'sepal length (cm)'}>,
#         <Axes: title={'center': 'sepal width (cm)'}>],
#        [<Axes: title={'center': 'petal length (cm)'}>,
#         <Axes: title={'center': 'petal width (cm)'}>],
#        [<Axes: title={'center': 'target'}>, <Axes: >]], dtype=object)

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
pd.plotting.scatter_matrix(df, c=iris.target, figsize=(10, 10));

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.5,random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
sca=StandardScaler()
sca.fit(x_train)

xx=sca.transform(x_train)
x_train
# Out:
# array([[4.3, 1.3],
#        [5.5, 1.8],
#        [3.3, 1. ],
#        [6. , 2.5],
#        [4. , 1.3],
#        [1.5, 0.2],
#        [1.5, 0.2],
#        [1.5, 0.1],
#        [5.7, 2.1],
#        [1.3, 0.2],
#        [5.1, 1.6],
#        [5.3, 1.9],
#        [5.1, 1.8],
#        [1.5, 0.2],
#        [1.7, 0.5],
#        [4.1, 1. ],
#        [1.5, 0.1],
#        [6.1, 1.9],
#        [4.3, 1.3],
#        [6.6, 2.1],
#        [5.2, 2.3],
#        [4.4, 1.3],
#        [5.4, 2.3],
#        [6.1, 2.5],
#        [3.6, 1.3],
#        [1.5, 0.4],
#        [3.9, 1.2],
#        [1.3, 0.3],
#        [3.8, 1.1],
#        [4.9, 1.5],
#        [1.6, 0.4],
#        [4.8, 1.4],
#        [1.6, 0.6],
#        [1.9, 0.2],
#        [5.6, 2.4],
#        [4.9, 2. ],
#        [5.9, 2.3],
#        [1.4, 0.2],
#        [1.5, 0.4],
#        [4.8, 1.8],
#        [1.5, 0.2],
#        [5.1, 1.9],
#        [1.6, 0.2],
#        [5.2, 2. ],
#        [4.5, 1.7],
#        [1.4, 0.2],
#        [5.3, 2.3],
# ...

# %%
test_acc={}
for i in range(1,15):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)
    pred=knn.predict(x_test)
    test_acc[i]=accuracy_score(pred,y_test)*100
print(sorted(test_acc.items(),key=lambda  item:item[-1]))
# Out:
# [(1, 92.0), (2, 93.33333333333333), (11, 94.66666666666667), (13, 94.66666666666667), (8, 96.0), (10, 96.0), (12, 96.0), (14, 96.0), (7, 97.33333333333334), (9, 97.33333333333334), (3, 98.66666666666667), (4, 98.66666666666667), (5, 98.66666666666667), (6, 98.66666666666667)]

# %%
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=14)

# %%
b=knn.predict([[2,3]])
iris.target_names[b]
# Out:
# array(['versicolor'], dtype='<U10')

# %%
# Out:
# 0.9083333333333333

# %%
# Out:
# [1.0, 0.9666666666666667, 0.9666666666666667, 0.9666666666666667, 0.9666666666666667, 0.9666666666666667, 0.9666666666666667, 0.9333333333333333, 0.9666666666666667, 0.9666666666666667]
# [0.9666666666666667, 0.9416666666666667, 0.95, 0.95, 0.95, 0.95, 0.95, 0.9083333333333333, 0.925, 0.9083333333333333]
